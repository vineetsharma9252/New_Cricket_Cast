# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.metrics import r2_score

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('Featured_Matches_with_Deliveries.csv')

# %%
df.head(10)
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 5    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 6    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 7    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     1
# 8    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     1
# 9    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     1
#
#    ball       batter   bowler  non_striker  batsman_runs  ...  score  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0  ...      1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0  ...      1
# 2     3  BB McCullum  P Kumar   SC Ganguly             0  ...      2
# 3     4  BB McCullum  P Kumar   SC Ganguly             0  ...      2
# 4     5  BB McCullum  P Kumar   SC Ganguly             0  ...      2
# 5     6  BB McCullum  P Kumar   SC Ganguly             0  ...      2
# 6     7  BB McCullum  P Kumar   SC Ganguly             0  ...      3
# 7     1  BB McCullum   Z Khan   SC Ganguly             0  ...      3
# 8     2  BB McCullum   Z Khan   SC Ganguly             4  ...      7
# 9     3  BB McCullum   Z Khan   SC Ganguly             4  ...     11
#
#                          team1 Neutral  is_home_team final_innings_score  \
# 0  Royal Challengers Bangalore     NaN         False                 222
# 1  Royal Challengers Bangalore     NaN         False                 222
# 2  Royal Challengers Bangalore     NaN         False                 222
# 3  Royal Challengers Bangalore     NaN         False                 222
# 4  Royal Challengers Bangalore     NaN         False                 222
# 5  Royal Challengers Bangalore     NaN         False                 222
# 6  Royal Challengers Bangalore     NaN         False                 222
# 7  Royal Challengers Bangalore     NaN         False                 222
# 8  Royal Challengers Bangalore     NaN         False                 222
# 9  Royal Challengers Bangalore     NaN         False                 222
#
#   batter_code  bowler_code non_striker_code batting_team_code  \
# 0           1           14                2                 1
# 1           2           14                1                 1
# 2           2           14                1                 1
# 3           2           14                1                 1
# 4           2           14                1                 1
# 5           2           14                1                 1
# 6           2           14                1                 1
# 7           2           15                1                 1
# 8           2           15                1                 1
# 9           2           15                1                 1
#
#    bowling_team_code
# 0                  2
# 1                  2
# 2                  2
# 3                  2
# 4                  2
# 5                  2
# 6                  2
# 7                  2
# 8                  2
# 9                  2
#
# [10 rows x 26 columns]

# %%
print(df.columns)
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batter', 'bowler', 'non_striker', 'batsman_runs', 'extra_runs',
#        'total_runs', 'extras_type', 'is_wicket', 'player_dismissed',
#        'dismissal_kind', 'score', 'team1', 'Neutral', 'is_home_team',
#        'final_innings_score', 'batter_code', 'bowler_code', 'non_striker_code',
#        'batting_team_code', 'bowling_team_code'],
#       dtype='object')

# %%
df.drop(['match_id','Neutral','team1','score','batsman_runs', 'extra_runs',
         'extras_type', 'is_wicket', 'player_dismissed','dismissal_kind',
         'batter', 'bowler', 'non_striker','batting_team', 'bowling_team'],axis=1, inplace=True)

# %%
df.head(5)
# Out:
#    inning  over  ball  total_runs  is_home_team  final_innings_score  \
# 0       1     0     1           1         False                  222
# 1       1     0     2           0         False                  222
# 2       1     0     3           1         False                  222
# 3       1     0     4           0         False                  222
# 4       1     0     5           0         False                  222
#
#    batter_code  bowler_code  non_striker_code  batting_team_code  \
# 0            1           14                 2                  1
# 1            2           14                 1                  1
# 2            2           14                 1                  1
# 3            2           14                 1                  1
# 4            2           14                 1                  1
#
#    bowling_team_code
# 0                  2
# 1                  2
# 2                  2
# 3                  2
# 4                  2

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop(['final_innings_score'], axis=1), df['final_innings_score'], test_size=0.2, random_state=42)

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
r2 = r2_score(y_test, y_pred)
r2
# Out:
# -0.14554664710618193

# %%
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
r2 = r2_score(y_test, y_pred)
r2
# Out:
# 0.09909041663212337

# %%
model = ExtraTreesRegressor(n_estimators=100, max_depth=20, random_state=42)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
r2 = r2_score(y_test, y_pred)
r2
# Out:
# 0.7582753483844271

# %%
custom_input = pd.DataFrame([{
    'inning': 2,
    'over': 10,
    'ball': 3,
    'total_runs': 100,
    'is_home_team': True,
    'batter_code': 150,
    'bowler_code': 230,
    'non_striker_code': 99,
    'batting_team_code': 2,
    'bowling_team_code': 5
}])

# %%
y_pred = model.predict(custom_input)

# %%
y_pred
# Out:
# array([138.43612534])
